# %% [markdown]
# ## ** PANDAS TASK SOLUTION 24-JULY **

# %% [markdown]
# ### Question:
# Mysql :
#
#     1. Create a  table attribute dataset and dress dataset
#     2. Do a bulk load for these two table for respective dataset
#     3. read these dataset in pandas as a dataframe
#     4. Convert attribute dataset in json format
#     5. Store this dataset into mongodb
#     6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
#     7. Write a sql query to find out how many unique dress that we have based on dress id
#     8. Try to find out how mnay dress is having recommendation 0
#     9. Try to find out total dress sell for individual dress id
#     10. Try to find out a third highest most selling dress id

# %% [markdown]
# ### used dataset is available Here:
#
# https://drive.google.com/drive/folders/1vdLTTFQczfXW5o__f1ce5WfDqfI5JYAF

# %%
# !pip install mysql-connector-python

# %%
import pandas as pd

# %%
import mysql.connector as conn
mydb=conn.connect(host='localhost',user='root',passwd='mysql1234',database="pdtask")

# %%
print(mydb)

# %%
cursor=mydb.cursor()

# %% [markdown]
# ### 1-Create a Table of attribute dataset and dress dataset in mysql workbench/python
# ### 2-Do a bulk load for these two table for respective dataset

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('pdtask',),
#  ('performance_schema',),
#  ('sudhanshu',),
#  ('sys',),
#  ('world',)]

# %%
##Create table for Attribute Dataset in mysql workbench

show databases
create database if not exists pdtask
use pdtask


create table if not Exists attri_data(
Dress_ID int,
style varchar(30),
price varchar(30),
rating float(4,3),
size varchar(30),
season varchar(30),
NeckLine varchar(30),
SleevLenght varchar(30),
WaiseLine varchar(30),
Material varchar(30),
FebricType varchar(30),
Decoration varchar(30),
PettenType varchar(30) ,
Recommendation int);

#Inserting Attribute Dataset Records
LOAD DATA INFILE 'C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\Attribute DataSet.csv' INTO TABLE attri_data
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\n';


select * from attri_data #coming data properly

# %%
#Creating table for Dress Sales in sqlworkbench

create table if not exists  dress_sales(

Dress_id int,
`29/8/2013` INT,
`31/8/2013` INT,
`02/09/2013` INT,
`04/09/2013` INT,
`06/09/2013` INT,
`08/09/2013` INT,
`10/09/2013` INT,
`12/09/2013` INT,
`14/9/2013` INT,
`16/9/2013` INT,
`18/9/2013` INT,
`20/9/2013` INT,
`22/9/2013` INT,
`24/9/2013` INT,
`26/9/2013` INT,
`28/9/2013` INT,
`30/9/2013` INT,
`2/10/2013` INT,
`4/10/2013` INT,
`6/10/2013` INT,
`8/10/2013` INT,
`10/10/2013` INT,
`12/10/2013` INT
);

#Inserting Attribute Dataset Records
LOAD DATA INFILE 'C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\Dress Sales.csv' INTO TABLE Dress_sales
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\r\n'
IGNORE 1 LINES;



select * from dress_sales #coming data properly

# %% [markdown]
# ### 3. read these dataset in pandas as a dataframe

# %%
#Run SQL

sql_Q1=pd.read_sql('select *from pdtask.attri_data',mydb)

sql_Q2=pd.read_sql('select* from pdtask.dress_sales',mydb)

# %%
#Converting SQL to DataFrame

attribute_data_f = pd.DataFrame(sql_Q1,columns=['dress_id','style','price','rating','size','season','neckline',
                                        'sleevelength','waiseline','material','fabrictype','decoration',
                                        'patterntype','recommendation'])

dress_sales_f = pd.DataFrame(sql_Q2, columns = ['dress_id','29/8/2013', '31/8/2013', '2/9/2013','4/9/2013','6/9/2013','8/9/2013','10/9/2013',
                                        '12/9/2013','14/9/2013','16/9/2013','18/9/2013','20/9/2013','22/9/2013','24/9/2013'
                                        '24/9/2013','26/9/2013','28/9/2013','30/9/2013','2/10/2013','4/10/2013','6/10/2013',
                                        '8/10/2013','10/10/2013','12/10/2013'])

# %%
attribute_data_f
# Out:
#      dress_id    style    price  rating  size  season  neckline  sleevelength  \
# 0         NaN     Sexy      Low     4.6     M  Summer       NaN           NaN
# 1         NaN   Casual      Low     0.0     L  Summer       NaN           NaN
# 2         NaN  vintage     High     0.0     L  Automn       NaN           NaN
# 3         NaN    Brief  Average     4.6     L  Spring       NaN           NaN
# 4         NaN     cute      Low     4.5     M  Summer       NaN           NaN
# ..        ...      ...      ...     ...   ...     ...       ...           ...
# 495       NaN   Casual      Low     4.7     M  Spring       NaN           NaN
# 496       NaN     Sexy      Low     4.3  free  Summer       NaN           NaN
# 497       NaN   Casual  Average     4.7     M  Summer       NaN           NaN
# 498       NaN   Casual  Average     4.6     L  winter       NaN           NaN
# 499       NaN   Casual      Low     4.4  free  Summer       NaN           NaN
#
# ...

# %%
dress_sales_f
# Out:
#      dress_id  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0         NaN       2114       2274       NaN       NaN       NaN       NaN
# 1         NaN        151        275       NaN       NaN       NaN       NaN
# 2         NaN          6          7       NaN       NaN       NaN       NaN
# 3         NaN       1005       1128       NaN       NaN       NaN       NaN
# 4         NaN        996       1175       NaN       NaN       NaN       NaN
# ..        ...        ...        ...       ...       ...       ...       ...
# 495       NaN          0          0       NaN       NaN       NaN       NaN
# 496       NaN          0          0       NaN       NaN       NaN       NaN
# 497       NaN          0          0       NaN       NaN       NaN       NaN
# 498       NaN          0          0       NaN       NaN       NaN       NaN
# 499       NaN          0          0       NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ### 4. Convert attribute dataset in json format

# %%
attribute_data_json=attribute_data_f.to_json('attri.json')

# %% [markdown]
# ### 5. Store this dataset into mongodb

# %%
import pymongo
import json

client = pymongo.MongoClient("mongodb+srv://mongodb:Rohit123@cluster0.4jhuusd.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-fu7xisf-shard-00-01.4jhuusd.mongodb.net:27017', 'ac-fu7xisf-shard-00-00.4jhuusd.mongodb.net:27017', 'ac-fu7xisf-shard-00-02.4jhuusd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-nzgna6-shard-0', tls=True), 'test')

# %%
#Creating Database
database=client['task']

#Creating Collection/Document inside Database 

collection=database['jsontable']

# %%
#Storing JSON Data into MongoDB
#Loading or Opening the json file

with open('attri.json') as f:
    file_data=json.load(f)

# Inserting the loaded data in the Collection
# if JSON contains data more than one entry
# insert_many is used else insert_one is used

if isinstance(file_data,list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# %% [markdown]
# ### 6.perform left join operation with attrubute dataset and dress dataset on column Dress_ID

# %%
joined_data = pd.merge(attribute_data_f,dress_sales_f,how = 'left',on = 'dress_id')
print(joined_data)
# Out:
#         dress_id   style price  rating  size  season  neckline  sleevelength  \
# 0            NaN    Sexy   Low     4.6     M  Summer       NaN           NaN
# 1            NaN    Sexy   Low     4.6     M  Summer       NaN           NaN
# 2            NaN    Sexy   Low     4.6     M  Summer       NaN           NaN
# 3            NaN    Sexy   Low     4.6     M  Summer       NaN           NaN
# 4            NaN    Sexy   Low     4.6     M  Summer       NaN           NaN
# ...          ...     ...   ...     ...   ...     ...       ...           ...
# 249995       NaN  Casual   Low     4.4  free  Summer       NaN           NaN
# 249996       NaN  Casual   Low     4.4  free  Summer       NaN           NaN
# 249997       NaN  Casual   Low     4.4  free  Summer       NaN           NaN
# 249998       NaN  Casual   Low     4.4  free  Summer       NaN           NaN
# 249999       NaN  Casual   Low     4.4  free  Summer       NaN           NaN
#
# ...

# %% [markdown]
# ### 7. Write a sql query to find out how many unique dress that we have based on dress id

# %%
cursor.execute('select count(distinct(dress_id)) from pdtask.attri_data')

# %%
for i in cursor.fetchall():
    print(i) # output (475,)
# Out:
# (475,)

# %% [markdown]
# ### 8. Try to find out how mnay dress is having recommendation 0

# %%
cursor.execute('select count(recommendation) from attri_data where recommendation=0') # by sql
cursor.fetchall() # 290
# Out:
# [(290,)]

# %% [markdown]
# ### 9. Try to find out total dress sell for individual dress id

# %%
#Creating Column Total Sales for each Dress ID
dress_sales_f['Sales'] = dress_sales_f[['29/8/2013', '31/8/2013', '2/9/2013','4/9/2013','6/9/2013','8/9/2013','10/9/2013',
                                        '12/9/2013','14/9/2013','16/9/2013','18/9/2013','20/9/2013','22/9/2013'
                                        ,'26/9/2013','28/9/2013','30/9/2013','2/10/2013','4/10/2013','6/10/2013',
                                        '8/10/2013','10/10/2013','12/10/2013']].agg('sum', axis=1)

# %%
print(dress_sales_f.groupby('dress_id')['Sales'].sum())
# Out:
# Series([], Name: Sales, dtype: float64)

# %% [markdown]
# ### 10.Try to find out the third highest most selling Dress_ID

# %%
#Task 10
#Try to find out the third highest most selling Dress_ID
sales_data = dress_sales_f.groupby('dress_id')['Sales'].sum().reset_index().rename(columns={'sum':'Sales','dress_id' : 'dress_id'})
print(sales_data)


#If we have to do in SQL then query will be
# SELECT DISTINCT SALES AS 3RDHighestSales
# FROM DRESS_SALES_TABLE
# ORDER BY SALES DESC
# LIMIT 1 
# OFFSET 2;
# Out:
# Empty DataFrame
# Columns: [dress_id, Sales]
# Index: []

# %%
print(sales_data.Sales.nlargest(3).iloc[-1]) #Getting 75979 as 3rd largest sum
